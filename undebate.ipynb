# %% [markdown]
# <a href="https://colab.research.google.com/github/Emekaborisama/100Days_of_DataScience/blob/master/undebate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Initialize google drive and directory

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %% [markdown]
# Display files in your folder

# %%
# !ls "/content/drive/My Drive/detm"
# Out:
# data_matlab.mat  min_df_10		 results		utils.py
# data.py		 plot_word_evolution.py  saved_result		vocab.pkl
# detm.py		 Plot_word_evo_un.png	 skipgram_emb_300d.txt
# main.py		 __pycache__		 timestamps.pkl

# %% [markdown]
# Change directory

# %%
import os
os.chdir("/content/drive/My Drive/detm")

# %% [markdown]
# Plot word evolution

# %%
# !python plot_word_evolution.py
# Out:
# beta:  (50, 46, 18896)
# timelist:  ['1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015']
# ticks:  ['1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015']
# Topic 0 .. Time: 0 ===> ['men', 'lusaka', 'imperialism', 'position', 'sale', 'possibly', 'examination', 'preparatory', 'committees']
# ...

# %% [markdown]
# Run Detm on UN Debate dataset

# %%
# !python main.py --dataset data_matlab.mat --data_path min_df_10/ --emb_path skipgram_emb_300d.txt --min_df 10 --num_topics 50 --lr 0.0001 --epochs 1000 --num_words 30 --mode train
# Out:
# Streaming output truncated to the last 5000 lines.
# Topic 39 .. Time: 10 ===> ['independence', 'results', 'attempts', 'proposals', 'field', 'southeast', 'apartheid', 'developed', 'means', 'threat', 'fact', 'blocs', 'imperialism', 'determination', 'malta', 'vast', 'remain', 'france', 'colonialism', 'legitimate', 'fully', 'sense', 'helsinki', 'africa', 'iran', 'adequate', 'considers', 'designed', 'restore']
# Topic 39 .. Time: 40 ===> ['areas', 'joseph', 'clear', 'commitment', 'relations', 'ensuring', 'crime', 'palestinian', 'china', 'sources', 'worldwide', 'damage', 'ability', 'faced', 'ban', 'league', 'meeting', 'programme', 'reiterate', 'universal', 'achieve', 'finance', 'strengthened', 'initiative', 'taking', 'peacekeeping', 'crucial', 'area', 'express']
# ...
